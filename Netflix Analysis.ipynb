# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('NetFlix.csv')
print(df)
# Out:
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 1        s10    Movie                                       1920
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.drop_duplicates(inplace=True)
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, genres, description]
# Index: []

# %%
df.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False      True  False    False       False
# 1       False  False  False     False  False    False       False
# 2       False  False  False     False  False    False       False
# 3       False  False  False     False  False    False       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 7782    False  False  False      True   True    False       False
# 7783    False  False  False      True  False    False       False
# 7784    False  False  False     False  False    False       False
# 7785    False  False  False     False  False    False       False
# 7786    False  False  False     False  False    False       False
#
#       release_year  rating  duration  genres  description
# 0            False   False     False   False        False
# ...

# %%
df1=df.dropna(axis=0)
df1.head()
# Out:
#   show_id   type                                      title         director  \
# 1     s10  Movie                                       1920     Vikram Bhatt
# 2    s100  Movie                                 3 Heroines   Iman Brotoseno
# 3   s1000  Movie  Blue Mountain State: The Rise of Thadland     Lev L. Spiro
# 5   s1002  Movie                                  Blue Ruin  Jeremy Saulnier
# 6   s1003  Movie                                Blue Streak     Les Mayfield
#
#                                                 cast                 country  \
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...                   India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...               Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...           United States
# 5  Macon Blair, Devin Ratray, Amy Hargreaves, Kev...   United States, France
# 6  Martin Lawrence, Luke Wilson, Peter Greene, Da...  Germany, United States
#
# ...

# %%
df1[df1['title'].str.contains('1920')] #director of 1920
# Out:
#   show_id   type title      director  \
# 1     s10  Movie  1920  Vikram Bhatt
#
#                                                 cast country date_added  \
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...   India  15-Dec-17
#
#    release_year rating  duration  \
# 1          2008  TV-MA       143
#
#                                            genres  \
# 1  Horror Movies, International Movies, Thrillers
#
#                                          description
# 1  An architect and his wife move into a castle t...

# %%
b=sns.barplot(x='type', y='release_year', data=df1)
#b.bar_label(b.containers[0])
plt.show() #In 2012 highest no. of movies released and 2016 highest no. of tv shows released

# %%
#how many movies and tv shows are there in dataset
c=sns.countplot(x='type', data=df1)
c.bar_label(c.containers[0])
plt.show() #4673 movies are there and 135 tv shows are there

# %%
#df1[df1['type'].str.contains('TV Show')]
data=df1[df1['type'].str.contains('TV Show') & (df1['country'].str.contains('India'))]
print(data['title']) #list the titles of the TV shows in India same followed as movie
# Out:
# 368                                 7 (Seven)
# 1565                                    GHOUL
# 2358             Jamtara - Sabka Number Ayega
# 4140                          Paava Kadhaigal
# 4815                             Sacred Games
# 5598    Th Eena Meena Deeka Chase Comedy Show
# Name: title, dtype: object

# %%
df['type'].value_counts()
# Out:
# type
# Movie      5377
# TV Show    2410
# Name: count, dtype: int64

# %%
df1['director'].value_counts().head(10) #top 10 directors who gave the highest no. of tv shows and movies
# Out:
# director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Johnnie To                 8
# Name: count, dtype: int64

# %%
#different ratings defined by Netflix
df['rating'].unique()
# Out:
# array(['TV-MA', 'TV-PG', 'R', 'TV-G', 'PG-13', 'TV-14', 'TV-Y', 'PG',
#        'TV-Y7', 'NR', 'G', 'TV-Y7-FV', nan, 'UR', 'NC-17'], dtype=object)

# %%
#how many movies have TV-MA reviews
d=df1[df1['rating'].str.contains('TV-MA') & (df1['country'].str.contains('Canada')) & df1['type'].str.contains('Movie')]
print(len(d['type']))
#60 movie have rating TV-MA reviews
# Out:
# 60

# %%
#how many Movie shows got R rating after year 2018
t=df1[df1['rating'].str.contains('R') & (df1['release_year']>2018) &(df1['type'].str.contains('Movie'))]
print(len(t['type']))
#70
# Out:
# 70
#      show_id   type                    title              director  \
# 312     s128  Movie            6 Underground           Michael Bay
# 556      s15  Movie                     3022            John Suits
# 635    s1570  Movie              Da 5 Bloods             Spike Lee
# 750    s1674  Movie              Death of Me   Darren Lynn Bousman
# 888    s1799  Movie      Dolemite Is My Name          Craig Brewer
# ...      ...    ...                      ...                   ...
# 7235   s7510  Movie   We Summon the Darkness           Marc Meyers
# 7257   s7530  Movie  Welcome to Sudden Death        Dallas Jackson
# 7308   s7577  Movie        Wheels of Fortune  Shaun Paul Piccinino
# 7371   s7633  Movie             Wine Country           Amy Poehler
# 7458   s7711  Movie            Yes, God, Yes           Karen Maine
#
#                                                    cast  \
# 312   Ryan Reynolds, Mélanie Laurent, Corey Hawkins,...
# ...
